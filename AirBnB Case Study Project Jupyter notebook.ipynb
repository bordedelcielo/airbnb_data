# %% [markdown]
# # AirBnB NY Locations Data Case Study
#
# In this final project, you task will be to take the data provided and find evidance to answer the following questions.
#
# 1. Which hosts are the busiest and why?
# 2. How many neighborhood groups are available and which shows up the most?
# 3. Are private rooms the most popular in manhattan?
# 4. Which hosts are the busiest and based on their reviews?
# 5. Which neighorhood group has the highest average price?
# 6. Which neighborhood group has the highest total price?
# 7. Which top 5 hosts have the highest total price?
# 8. Who currently has no (zero) availability with a review count of 100 or more?
# 9. What host has the highest total of prices and where are they located?
# 10. When did Danielle from Queens last receive a review?
#
# You will be given **4 hours** to complete this assignment.
# **Be Advised** I will go dark for this intire assignment time period. That said, any questions that you would like to ask about the data, or the project **MUST** be asked before the time starts. Once the time has started, I can no longer give information.
#
# This is to similate what you will face when you are out in the wild.
#
# Happy Coding!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
air_bnb = pd.read_csv('files/AB_NYC_2019.csv')
air_bnb.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
# How many neighborhood groups are available and which shows up the most?

# There are five available neighborhood groups.
# Manhattan is the most common with a frequency of 21,661 
# (nearly 50% of the total listings).

air_bnb['neighbourhood_group'].describe()
# Out:
# count         48895
# unique            5
# top       Manhattan
# freq          21661
# Name: neighbourhood_group, dtype: object

# %%
# Are private rooms the most popular in manhattan?

# They are not. Entire home/apt is.

air_bnb.groupby(['neighbourhood_group', 'room_type']).count().sort_values('neighbourhood_group', ascending = False)
# Out:
#                                         id   name  host_id  host_name  \
# neighbourhood_group room_type
# Staten Island       Entire home/apt    176    176      176        176
#                     Private room       188    188      188        188
#                     Shared room          9      9        9          9
# Queens              Entire home/apt   2096   2096     2096       2096
#                     Private room      3372   3372     3372       3370
#                     Shared room        198    198      198        198
# Manhattan           Entire home/apt  13199  13193    13199      13196
#                     Private room      7982   7979     7982       7976
#                     Shared room        480    480      480        480
# Brooklyn            Entire home/apt   9559   9558     9559       9554
#                     Private room     10132  10127    10132      10128
#                     Shared room        413    413      413        413
# ...

# %%
# Which hosts are the busiest and based on their reviews?

# Row NYC, Louann, and Naicia if counted by reviews per month. If counted by total number, Dona and Jj.

air_bnb.groupby(['host_name', 'reviews_per_month']).count().sort_values('reviews_per_month', ascending = False)
# air_bnb.groupby(['host_name', 'number_of_reviews']).count().sort_values('number_of_reviews', ascending = False)
# Out:
#                              id  name  host_id  neighbourhood_group  \
# host_name reviews_per_month
# Row NYC   58.50               1     1        1                    1
#           27.95               1     1        1                    1
# Louann    20.94               1     1        1                    1
# Nalicia   19.75               1     1        1                    1
#           17.82               1     1        1                    1
# ...                          ..   ...      ...                  ...
# Fredah    0.01                1     1        1                    1
# Rebecca   0.01                1     1        1                    1
# Shahdiya  0.01                1     1        1                    1
# Enid      0.01                1     1        1                    1
# Jazmin    0.01                1     1        1                    1
#
#                              neighbourhood  latitude  longitude  room_type  \
# host_name reviews_per_month
# ...

# %%
#Which neighorhood group has the highest average price?
# Manhattan.

air_bnb.groupby('neighbourhood_group').mean()[['price']]
# Out:
#                           price
# neighbourhood_group
# Bronx                 87.496792
# Brooklyn             124.383207
# Manhattan            196.875814
# Queens                99.517649
# Staten Island        114.812332

# %%
# Which neighbor hood group has the highest total price?
# Summing the prices, Manhattan has the highest total price.
# Brooklyn, Manhattan, and Queens are tied with the maximum highest price at $10,000.00.

# air_bnb.groupby('neighbourhood_group').sum()[['price']]
air_bnb.groupby('neighbourhood_group').describe()[['price']]
# Out:
#                        price                                             \
#                        count        mean         std   min   25%    50%
# neighbourhood_group
# Bronx                 1091.0   87.496792  106.709349   0.0  45.0   65.0
# Brooklyn             20104.0  124.383207  186.873538   0.0  60.0   90.0
# Manhattan            21661.0  196.875814  291.383183   0.0  95.0  150.0
# Queens                5666.0   99.517649  167.102155  10.0  50.0   75.0
# Staten Island          373.0  114.812332  277.620403  13.0  50.0   75.0
#
#
#                        75%      max
# neighbourhood_group
# Bronx                 99.0   2500.0
# Brooklyn             150.0  10000.0
# Manhattan            220.0  10000.0
# Queens               110.0  10000.0
# Staten Island        110.0   5000.0

# %%
#Which top 5 hosts have the highest total price?

# Jelena, Erin, Kathrine, Matt, and Olson.

air_bnb.groupby(['host_name', 'price']).head().sort_values('price', ascending = False)
# Out:
#              id                                               name    host_id  \
# 29238  22436899                                1-BR Lincoln Center   72390391
# 17692  13894339    Luxury 1 bedroom apt. -stunning Manhattan views    5143901
# 9151    7003697                Furnished room in Astoria apartment   20582832
# 40433  31340283  2br - The Heart of NYC: Manhattans Lower East ...    4382127
# 6530    4737930                                 Spanish Harlem Apt    1235070
# ...         ...                                                ...        ...
# 26259  20933849                              the best you can find   13709292
# 25778  20624541      Modern apartment in the heart of Williamsburg   10132166
# 25433  20333471      ★Hostel Style Room | Ideal Traveling Buddies★  131697576
# 23161  18750597  Huge Brooklyn Brownstone Living, Close to it all.    8993084
# 25795  20639792  Contemporary bedroom in brownstone with nice view   86327101
#
# ...

# %%
# Who currently has no (zero) availability with a review count of 100 or more?

# 162 users.

# data['ages'] >= 25
grouped = air_bnb[air_bnb['number_of_reviews'] >= 100].groupby(['host_name', 'availability_365']).head().sort_values('availability_365', ascending = True)
grouped[grouped['availability_365'] == 0]

# air_bnb.groupby(['host_name', 'availability_365']).head().sort_values('availability_365', ascending = True)
# Out:
#              id                                               name    host_id  \
# 12908   9824042  21st Floor Bedroom in Doorman & Elevator Building   24175837
# 973      387735                  LOCATION LOCATION LOCATION Sara's    1146958
# 9976    7675781  JFK 10 & LGA 15 MINUTES  AWAY  A/C PRIVATE BED...   22959695
# 23260  18837416  *Luxury 1 Bedrm Private Designer Home & Roofdeck*    3203397
# 4945    3544828                PrivateRoom in Beautiful Brownstone   17224426
# ...         ...                                                ...        ...
# 13598  10167860        Sunny, Spacious Private BR in East Village!   21430239
# 8          5203                 Cozy Clean Guest Room - Family Apt       7490
# 13320  10017359   Pre-War Charm with Modern Chic in Hell's Kitchen   36638599
# 30461  23574142                                  queens get away!!  176185168
# 5568    4050254         Mid-Century Modern En-Suite in Brownstone!    9492212
#
# ...

# %%
# What host has the highest total of prices and where are they located?

# Sonder (NYC). It is in the neighbourhood group Manhattan and operates in the Financial District, 
# Murray Hill, Hell's Kitchen, Midtown, the Theater District, Chelsea, and the Upper East Side.

grouped = (air_bnb[air_bnb['host_name'] == 'Sonder (NYC)'])
# grouped_copy = grouped['neighbourhood']
# grouped_copy_copy = grouped_copy.drop_duplicates('neighbourhood').reset_index(drop=True)
# grouped_copy_copy

grouped_copy = grouped.drop_duplicates('neighbourhood').reset_index(drop=True)
grouped_copy['neighbourhood']

# air_bnb.groupby('neighbourhood_group').sum()[['price']]
# air_bnb.groupby('host_name').sum()[['price']].sort_values('price', ascending = False)
# Out:
# 0    Financial District
# 1           Murray Hill
# 2        Hell's Kitchen
# 3               Midtown
# 4      Theater District
# 5               Chelsea
# 6       Upper East Side
# Name: neighbourhood, dtype: object

# %%
# When did Danielle from Queens last receive a review?
# Her last review was on July 7th, 2019.

# Getting host ID:
# grouped = air_bnb[air_bnb['host_name'] == 'Danielle']
# grouped[grouped['neighbourhood_group'] == 'Queens']
# host ID = 26432133. Chosen on the basis of being a prolific renter.

air_bnb[air_bnb['host_id'] == 26432133]
# Her last review was on July 7th, 2019.
# Out:
#              id                                               name   host_id  \
# 7086    5115372  Comfy Room Family Home LGA Airport NO CLEANING...  26432133
# 20403  16276632  Cozy Room Family Home LGA Airport NO CLEANING FEE  26432133
# 21517  17222454   Sun Room Family Home LGA Airport NO CLEANING FEE  26432133
# 22068  17754072                Bed in Family Home Near LGA Airport  26432133
# 22469  18173787  Cute Tiny Room Family Home by LGA NO CLEANING FEE  26432133
#
#       host_name neighbourhood_group  neighbourhood  latitude  longitude  \
# 7086   Danielle              Queens  East Elmhurst  40.76374  -73.87103
# 20403  Danielle              Queens  East Elmhurst  40.76335  -73.87007
# 21517  Danielle              Queens  East Elmhurst  40.76367  -73.87088
# 22068  Danielle              Queens  East Elmhurst  40.76389  -73.87155
# 22469  Danielle              Queens  East Elmhurst  40.76380  -73.87238
#
# ...

# %% [markdown]
# ## Further Questions
#
# 1. Which host has the most listings?

# %%
# air_bnb['calculated_host_listings_count'].describe()

# Sonder (NYC) has the most listings.

air_bnb[air_bnb['calculated_host_listings_count'] == 327]
# Out:
#              id                                               name    host_id  \
# 38293  30181691      Sonder | 180 Water | Incredible 2BR + Rooftop  219517861
# 38294  30181945         Sonder | 180 Water | Premier 1BR + Rooftop  219517861
# 38588  30347708        Sonder | 180 Water | Charming 1BR + Rooftop  219517861
# 39769  30937590            Sonder | The Nash | Artsy 1BR + Rooftop  219517861
# 39770  30937591        Sonder | The Nash | Lovely Studio + Rooftop  219517861
# ...         ...                                                ...        ...
# 47691  35871510  Sonder | 116 John | Vibrant Studio + Fitness Room  219517861
# 47692  35871511     Sonder | 116 John | Vibrant 1BR + Fitness Room  219517861
# 47693  35871515         Sonder | 116 John | Stunning 1BR + Rooftop  219517861
# 47814  35936418          Sonder | 116 John | Polished Studio + Gym  219517861
# 47821  35937891            Sonder | 116 John | Simple Studio + Gym  219517861
#
# ...

# %% [markdown]
# 2. How many listings have completely open availability?

# %%
air_bnb[air_bnb['availability_365'] == 365].count()

# 1295 listing ids.
# Out:
# id                                1295
# name                              1294
# host_id                           1295
# host_name                         1295
# neighbourhood_group               1295
# neighbourhood                     1295
# latitude                          1295
# longitude                         1295
# room_type                         1295
# price                             1295
# minimum_nights                    1295
# number_of_reviews                 1295
# last_review                        841
# reviews_per_month                  841
# calculated_host_listings_count    1295
# availability_365                  1295
# dtype: int64

# %% [markdown]
# 3. What room_types have the highest review numbers?

# %%
air_bnb.groupby('room_type').describe()[['number_of_reviews']]

# Entire home/apt has the highest count of reviews.
# Out:
#                 number_of_reviews                                              \
#                             count       mean        std  min  25%  50%    75%
# room_type
# Entire home/apt           25409.0  22.842418  42.408837  0.0  1.0  5.0  23.00
# Private room              22326.0  24.112962  47.286746  0.0  1.0  5.0  25.00
# Shared room                1160.0  16.600000  34.185006  0.0  0.0  4.0  16.25
#
#
#                    max
# room_type
# Entire home/apt  488.0
# Private room     629.0
# Shared room      454.0

# %% [markdown]
# # Final Conclusion
#
# In this cell, write your final conclusion for each of the questions asked.
#
# Also, if you uncovered some more details that were not asked above, please discribe them here.
#
# -- Add your conclusion --

# %%
# 1. Which hosts are the busiest and why?
# Row NYC, Louann, and Naicia if counted by reviews per month. If counted by total number, Dona and Jj.

# 2. How many neighborhood groups are available and which shows up the most?
# There are five available neighborhood groups.
# Manhattan is the most common with a frequency of 21,661 
# (nearly 50% of the total listings).

# 3. Are private rooms the most popular in manhattan?
# They are not. Entire home/apt is.

# 4. Which hosts are the busiest and based on their reviews?
# Row NYC, Louann, and Naicia if counted by reviews per month. If counted by total number, Dona and Jj.

# 5. Which neighorhood group has the highest average price?
# Manhattan.

# 6. Which neighborhood group has the highest total price?
# Summing the prices, Manhattan has the highest total price.
# Brooklyn, Manhattan, and Queens are tied with the maximum highest price at $10,000.00.

# 7. Which top 5 hosts have the highest total price?
# Jelena, Erin, Kathrine, Matt, and Olson.

# 8. Who currently has no (zero) availability with a review count of 100 or more?
# 162 users.

# 9. What host has the highest total of prices and where are they located?
# Sonder (NYC). It is in the neighbourhood group Manhattan and operates in the Financial District, 
# Murray Hill, Hell's Kitchen, Midtown, the Theater District, Chelsea, and the Upper East Side.

# 10. When did Danielle from Queens last receive a review?
# host ID = 26432133. Chosen on the basis of being a prolific renter.
# July 7th, 2019.

# 1.1. Which host has the most listings?
# Sonder (NYC) has the most listings at 327.

# 1.2. How many listings have completely open availability?
# 1295 listing ids.

# 1.3. What room_types have the highest review numbers?
# Entire home/apt has the highest count of reviews.
